# %%
import random
import sys
import pandas as pd
import warnings


title1= """
 █▒▒      █▒▒            █▒▒▒▒              █▒▒▒▒
  █▒▒   █▒▒            █▒▒    █▒▒         █▒    █▒▒
   █▒▒ █▒▒           █▒▒        █▒▒      █▒▒            █▒▒     █▒▒▒ █▒▒ █▒▒     █▒▒
     █▒▒       █▒▒▒  █▒▒        █▒▒      █▒▒          █▒▒  █▒▒   █▒▒  █▒  █▒▒  █▒   █▒▒
   █▒▒ █▒▒           █▒▒        █▒▒      █▒▒   █▒▒▒▒ █▒▒   █▒▒   █▒▒  █▒  █▒▒ █▒▒▒▒▒ █▒▒
  █▒▒   █▒▒            █▒▒     █▒▒        █▒▒    █▒  █▒▒   █▒▒   █▒▒  █▒  █▒▒ █▒
 █▒▒      █▒▒            █▒▒▒▒             █▒▒▒▒▒      █▒▒ █▒▒▒ █▒▒▒  █▒  █▒▒   █▒▒▒▒
"""

title2= """
               ______    __              __
              /      \  |  \            |  \
 ______ ____ |  ▓▓▓▓▓▓\_| ▓▓_    ______ | ▓▓__    __  _______     _______  ______  ______ ____
|      \    \| ▓▓_  \▓▓   ▓▓ \  /      \| ▓▓  \  |  \/       \   /       \/      \|      \    \
| ▓▓▓▓▓▓\▓▓▓▓\ ▓▓▓▓▓\  \▓▓▓▓▓▓ |  ▓▓▓▓▓▓\ ▓▓ ▓▓  | ▓▓  ▓▓▓▓▓▓▓  |  ▓▓▓▓▓▓▓  ▓▓▓▓▓▓\ ▓▓▓▓▓▓\▓▓▓▓\
| ▓▓ | ▓▓ | ▓▓ ▓▓       | ▓▓|  \ ▓▓__/ ▓▓ ▓▓ ▓▓__/ ▓▓_\▓▓▓▓▓▓\__| ▓▓_____| ▓▓__/ ▓▓ ▓▓ | ▓▓ | ▓▓
| ▓▓ | ▓▓ | ▓▓ ▓▓        \▓▓  ▓▓ ▓▓    ▓▓ ▓▓\▓▓    ▓▓       ▓▓  \\▓▓     \\▓▓    ▓▓ ▓▓ | ▓▓ | ▓▓
 \▓▓  \▓▓  \▓▓\▓▓         \▓▓▓▓| ▓▓▓▓▓▓▓ \▓▓ \▓▓▓▓▓▓ \▓▓▓▓▓▓▓ \▓▓ \▓▓▓▓▓▓▓ \▓▓▓▓▓▓ \▓▓  \▓▓  \▓▓
                               | ▓▓
                               | ▓▓ █▄▄░▀▄▀░░░█▄█▒▄▀▄░▄▀▀░█▄█▒███░█▄▒▄█░░░▄▀▀░█▄█▒▄▀▄░█▄░█░▄▀▀░█░▀█▀░█
                                \▓▓ █▄█░▒█▒▒░▒█▒█░█▀█▒▄▄▀▒█▒█░█▄▄░█▒▀▒█▒░░▀▄▄▒█▒█░█▀█░█▒▀█░▀▄█░█░█▄▄░█
"""
title3 = """
▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄
█░▄▄▀█░▄▀▄░██▄██░▄▄▀███░████▀▄▄▀█░▄▄█░▄▄██▄██░▄▄▀███░▄▄▀█░████░▄▀▄░█░▄▄▀█░▄▀██▄█
█░▀▀░█░█▄█░██░▄█░▀▀▄███░▄▄░█░██░█▄▄▀█░▄▄██░▄█░██░███░▀▀░█░▄▄░█░█▄█░█░▀▀░█░█░██░▄
█▄██▄█▄███▄█▄▄▄█▄█▄▄███▄██▄██▄▄██▄▄▄█▄▄▄█▄▄▄█▄██▄███▄██▄█▄██▄█▄███▄█▄██▄█▄▄██▄▄▄
▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
"""

print(title1)
print(title2)
print(title3)

#display board
def display_board():
    print('                               reference:')
    print('  '+board[1]+'  | '+board[2]+'  | '+board[3]+'   ',10*' ','  1  | 2  | 3  ')
    print('  '+board[4]+'  | '+board[5]+'  | '+board[6]+'   ',10*' ',"  4  | 5  | 6   ")
    print('  '+board[7]+'  | '+board[8]+'  | '+board[9]+'   ',10*' ',"  7  | 8  | 9    \n\n")

#game starter
def start_game():
    while True:
        start = input ('HI, Press \"1\" for New Game of \"2\" for Load saved game')
        if start == "1":
           set_mode1()
        elif start == "2":
           load_mode()
        else:
            print('one or two!! hey, can you Enter correct input?! omg!')

#choose mode game
def set_mode1():
      while True:
        global diff
        global set_mode
        diff = input ('Press to choose: \"1\" easy mode, \"2\" middle mode, \"3\" heavy mode')
        if diff == "1":
           set_mode=1
           main_game(set_mode)
        elif diff == "2":
           set_mode=1
           main_game(set_mode)
        elif diff == "3":
           set_mode=3
           main_game(set_mode)
        else:
            print('Dont be clumsy!! can you Enter correct input?!')

#load game
def load_mode():
  loaded_df = pd.read_csv('settings_game.csv')
  #convert to  dictionry
  loaded_values = dict(zip(loaded_df['function'], loaded_df['value']))
  #fill funnections
  set_mode = loaded_values.get('set_mode', 0)
  human = loaded_values.get('human', 0)
  cpu = loaded_values.get('cpu', 0)
  board = loaded_values.get('board', 0)
  main_game1(set_mode, human, cpu, board)

#choose sign
def user_choice():
    while True:
        inp = input('Choose your mark[x/o]: ')
        if inp in ['x' , 'X']:
            print('You choose "X".\n You play first.')
            return 'x','o'
        elif inp in ['O','o']:
            print('You choose "O".\n CPU plays first.')
            return 'o','x'
        else:
            print('hey looser can you enter correct option?!')

#main game
def main_game(set_mode):
    global board , human , cpu
    play = True
    board = [' ',' ',' ',' ',' ',' ',' ',' ',' ',' ']
    display_board()
    human , cpu = user_choice()
    while play:
        if human == 'x':
            x = human_input(human)
            board[x] = human
            display_board()
            play = win_check(human,cpu)
            if play:
                if set_mode == 1:
                   o = cpu_input1(board)
                   print(f'[CPU] Entered:{o}')
                   board[o] = cpu
                   display_board()
                   play = win_check(human,cpu)
                elif set_mode == 2:
                   o = cpu_input2(cpu,board,human)
                   print(f'[CPU] Entered:{o}')
                   board[o] = cpu
                   display_board()
                   play = win_check(human,cpu)
                else :
                   o =cpu_input3(cpu,human,board)
                   print(f'[CPU] Entered:{o}')
                   board[o] = cpu
                   display_board()
                   play = win_check(human,cpu)
        else:
          if set_mode == 1:
             x =cpu_input1(board)
             print(f'[CPU] Entered:{x}')
             board[x] = cpu
             display_board()
             play = win_check(human,cpu)
          elif set_mode == 2:
             x =cpu_input2(cpu,board,human)
             print(f'[CPU] Entered:{x}')
             board[x] = cpu
             display_board()
             play = win_check(human,cpu)
          else :
             x =cpu_input3(cpu,human,board)
             print(f'[CPU] Entered:{x}')
             board[x] = cpu
             display_board()
             play = win_check(human,cpu)
          if play:
              o = human_input(human)
              board[o] = human
              display_board()
              play = win_check(human , cpu)

#reloading game
def main_game1(set_mode, human, cpu, board):
    play = True
    display_board()
    while play:
        if human == 'x':
            x = human_input(human)
            board[x] = human
            display_board()
            play = win_check(human,cpu)
            if play:
                if set_mode == 1:
                   o = cpu_input1(board)
                   print(f'[CPU] Entered:{o}')
                   board[o] = cpu
                   display_board()
                   play = win_check(human,cpu)
                elif set_mode == 2:
                   o = cpu_input2(cpu,board,human)
                   print(f'[CPU] Entered:{o}')
                   board[o] = cpu
                   display_board()
                   play = win_check(human,cpu)
                else :
                   o =cpu_input3(cpu,human,board)
                   print(f'[CPU] Entered:{o}')
                   board[o] = cpu
                   display_board()
                   play = win_check(human,cpu)
        else:
          if set_mode == 1:
             x =cpu_input1(board)
             print(f'[CPU] Entered:{x}')
             board[x] = cpu
             display_board()
             play = win_check(human,cpu)
          elif set_mode == 2:
             x =cpu_input2(cpu,board,human)
             print(f'[CPU] Entered:{x}')
             board[x] = cpu
             display_board()
             play = win_check(human,cpu)
          else :
             x =cpu_input3(cpu,human,board)
             print(f'[CPU] Entered:{x}')
             board[x] = cpu
             display_board()
             play = win_check(human,cpu)
          if play:
              o = human_input(human)
              board[o] = human
              display_board()
              play = win_check(human , cpu)

# choose cell by User
def human_input(mark):
    while True:
        inp = input("choose a number beetwins 1-9 or 0 to quit:")
        if inp == '0':
           print(' OH, I know you were scared, you can continue the game later to lose! hahaha')
           saving_game()
        elif inp.isdigit() and int(inp) <10 and int(inp) >0:
            inp = int(inp)
            if board[inp] == " ":
                return inp
            else:
                print(f"'{mark}' place already taken.")
        else:
            print("are you crazy?! just enter a number beetwins 1-9 or 0 to quit. its very simple")

#choose cell by cpu mode easy
def cpu_input1(board):
    while True:
        number = random.randint(1, 9)
        if board[number - 1] == ' ':
            return number
        elif all(val != ' ' for val in board):
            return None

#choose cell by cpu mode normal
def cpu_input2(cpu, board, human):
    board_empty = [i for i, cell in enumerate(board, start=1) if cell == '']
    for i in range(1,10):
        if board[i] == ' ' and win_move(i,board,human):
            return i
        else:
            return random.choice(board_empty)

#choose cell by cpu mode heavy
def cpu_input3(cpu , human , board):
    for i in range(1,10):
        if board[i] == ' ' and win_move(i,board,cpu):
            return i
    for i in range(1,10):
        if board[i] == ' ' and win_move(i,board,human):
            return i
    for i in [5,1,7,3,2,9,8,6,4]:
        if board[i] == ' ':
            return i

#winning pottern
global winning_place
winning_place = [[1,2,3],[4,5,6],[7,8,9],[1,4,7],[2,5,8],[3,6,9],[1,5,9],[3,5,7]]

def winning(mark,board):
       for win_place in winning_place:
        if board[win_place[0]] == board[win_place[1]] == board[win_place[2]] == mark:
            return True

#winnig move
def win_move(i,board,mark):
    temp_board = list(board)
    temp_board[i] = mark
    if winning(mark,temp_board):
        return True
    else:
        return False

#check winner
def win_check(human , cpu):
    for win_place in winning_place:
        if board[win_place[0]] == board[win_place[1]] == board[win_place[2]] ==human:
            print('Your wins, It was just luck,I will win again next time!')
            if not new_game():
                return False
        elif board[win_place[0]] == board[win_place[1]] == board[win_place[2]] == cpu:
                print('You are looser, dont cry!')
                if not new_game():
                    return False
    if ' ' not in board:
        print('MATCH DRAW!!')
        if not new_game():
            return False
    return True

#new game start
def new_game():
    while True:
        nxt = input('Do you want to play again?(y/n):')
        if nxt in['y','Y']:
            again = True
            set_mode1()
        elif nxt in ['n','N']:
            print('ok, by looser! see you later')
            again = False
            quit_game()
            break
        else:
            print('hey looser! can you Enter correct input?')
    if again:
        print('__________NEW GAME__________')
        start_game()
    else:

        return False

#close game
global quit
quit = False

def quit_game():
    warnings.filterwarnings("ignore")
    sys.exit(0)

#saving game
def saving_game():
   set_mode_values = {
    'set_mode': set_mode,
    'human': human,
    'cpu': cpu,
    'board': board
  }
   df = pd.DataFrame(set_mode_values.items(), columns=['function', 'value'])
   #saving game to CSV
   df.to_csv('settings_game.csv', index=False)
   print("see You later, looser! hahaha.")
   quit_game()

if __name__ == '__main__':
    start_game()
    quit_game()
